-- %%
-- ==========================================================
-- Player Ranking Analysis
-- ==========================================================
-- Question:
-- How can players be ranked based on their overall performance
-- to identify the top-performing players?
--
-- Metrics:
-- performance_rank
-- performance_score
-- win_rate
-- kd_ratio
-- avg_accuracy
-- mvp_count
-- ==========================================================
